# %% [markdown]
# <a href="https://colab.research.google.com/github/Janemugoo/Sales-Performance-Analysis-Dashboard-Excel-/blob/main/SuperStore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel('/content/Sample - Superstore Project.xlsx')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df.head(30)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 1        2  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 2        3  CA-2016-138688 2016-12-06 2016-06-16    Second Class    DV-13045
# 3        4  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
# 4        5  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
# 5        6  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 6        7  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 7        8  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 8        9  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 9       10  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 10      11  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# ...

# %%
df['Order Year'] = df['Order Date'].dt.year
df['Order Month'] = df['Order Date'].dt.month
df['Ship Year'] = df['Ship Date'].dt.year
df['Ship Month'] = df['Ship Date'].dt.month

# %%
df.head(25)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 1        2  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 2        3  CA-2016-138688 2016-12-06 2016-06-16    Second Class    DV-13045
# 3        4  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
# 4        5  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
# 5        6  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 6        7  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 7        8  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 8        9  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 9       10  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# 10      11  CA-2014-115812 2014-09-06 2014-06-14  Standard Class    BH-11710
# ...

# %%
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')

# %%
df.tail(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-03-10  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-04-05 2017-09-05    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
df=df.drop_duplicates()

# %%
df.to_csv('cleaned_Superstore_data.csv', index=False)
print("Data Cleaned and Saved")
# Out:
# Data Cleaned and Saved
